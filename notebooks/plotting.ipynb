# %%
# import the relevant modules
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

from scipy.stats import pearsonr
from sklearn.utils import resample

# %%
import sys
sys.path.append('../dictionaries')
sys.path.append('../functions')

import dictionaries
import functions

# %%
# First import the observation dataset
obs = xr.open_dataset(dictionaries.obs_long, chunks={'time': 10})

# Now import the model data
# Using the load_ensemble_members function from functions.py
datasets_by_model = functions.load_ensemble_members(dictionaries.JASMIN_ind_dir, dictionaries.models)

# %%
# Now process the data to get the NAO index
# For the observations first
# Using the process_model_dataset function from functions.py
# Which is nested inside the process_ensemble_members function
# ---- THIS MIGHT NOT WORK ----
obs_nao_anom, obs_time = functions.process_observations(obs)

# Now process the individual ensemble members
# Using the process_ensemble_members function from functions.py
# ---- THIS MIGHT NOT WORK EITHER ----
model_time_by_model, model_nao_anoms_by_model = functions.process_ensemble_members(datasets_by_model)
# Out:
# (56,)
# (56,)

# %%
# test the function to plot the ensemble members and stats
# default is 10 ensemble members
functions.plot_random_ensemble_members_and_stats(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)
# Out:
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>

# %%
# for 50 members
functions.plot_random_ensemble_members_and_stats(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=50)
# Out:
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>

# %%
# for 100 members
functions.plot_random_ensemble_members_and_stats(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=100)
# Out:
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>
# model times ['1966' '1967' '1968' '1969' '1970' '1971' '1972' '1973' '1974' '1975'
#  '1976' '1977' '1978' '1979' '1980' '1981' '1982' '1983' '1984' '1985'
#  '1986' '1987' '1988' '1989' '1990' '1991' '1992' '1993' '1994' '1995'
#  '1996' '1997' '1998' '1999' '2000' '2001' '2002' '2003' '2004' '2005'
#  '2006' '2007' '2008' '2009' '2010' '2011' '2012' '2013' '2014' '2015'
#  '2016' '2017' '2018' '2019']
# model times shape (54,)
# model times type <class 'numpy.ndarray'>

# %%
# # for 150 members
# functions.plot_random_ensemble_members_and_stats(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=150)

# %%
# same as above but with optimization for high ACC scores
# using greedy otimization
functions.plot_random_ensemble_members_and_stats_optimize(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=10)
# Out:
# ensemble_members_array shape: (178, 54)
# ensemble_members_array type: <class 'numpy.ndarray'>
# ensemble_members_time shape: (54,)
# ensemble_members_time type: <class 'numpy.ndarray'>
# model times ['1969' '1970' '1971' '1972' '1973' '1974' '1975' '1976' '1977' '1978'
#  '1979' '1980' '1981' '1982' '1983' '1984' '1985' '1986' '1987' '1988'
#  '1989' '1990' '1991' '1992' '1993' '1994' '1995' '1996' '1997' '1998'
#  '1999' '2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007' '2008'
#  '2009' '2010' '2011' '2012' '2013' '2014' '2015' '2016' '2017' '2018'
#  '2019']
# model times shape (51,)
# model times type <class 'numpy.ndarray'>
# model times ['1969' '1970' '1971' '1972' '1973' '1974' '1975' '1976' '1977' '1978'
#  '1979' '1980' '1981' '1982' '1983' '1984' '1985' '1986' '1987' '1988'
#  '1989' '1990' '1991' '1992' '1993' '1994' '1995' '1996' '1997' '1998'
#  '1999' '2000' '2001' '2002' '2003' '2004' '2005' '2006' '2007' '2008'
# ...

# %%
# 50 members
functions.plot_random_ensemble_members_and_stats_optimize(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=50)

# %%
# # 100 members
# functions.plot_random_ensemble_members_and_stats_optimize(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=100)

# %%
# # 150 members
# functions.plot_random_ensemble_members_and_stats_optimize(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=150)

# %%
# # 178 members
# # cpu go brrrrr
# functions.plot_random_ensemble_members_and_stats_optimize(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=178)

# %%
# # test the plotting fucntion for looking at the noise
# functions.plot_ensemble_members_and_obs(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, plot_obs=False)

# %%
# # test the plotting fucntion for looking at the noise
# functions.plot_ensemble_members_and_obs(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=50, plot_obs=False)

# %%
# # test the plotting fucntion for looking at the noise
# functions.plot_ensemble_members_and_obs(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=50)

# %%
# # test the plotting fucntion for looking at the noise
# functions.plot_ensemble_members_and_obs(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=100)

# %%
# # test the plotting fucntion for looking at the noise
# functions.plot_ensemble_members_and_obs(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time, no_ensemble_members=150)

# %%
# # Now call the plotting function
# # plot_ensemble_members_and_mean function from functions.py
# # ---- THIS MIGHT NOT WORK EITHER ----
# functions.plot_ensemble_members_and_mean(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# # Test whether the function works with Doug and Marcheggiani models
# # Slightly lowe skill - maybe?
# functions.plot_ensemble_members_and_mean(dictionaries.marcheg_models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# # Test with doug models
# functions.plot_ensemble_members_and_mean(dictionaries.smith_cmip6_models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# Test the lagged and adjusted variance plotting function
functions.plot_ensemble_members_and_lagged_adjusted_mean(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# Test the plotting subplots function
functions.plot_subplots_ensemble_members_and_mean(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# Now test the lagged and var adjust plotting script
# The code for this will need to be updated with changes
# To how the function is lagged
# functions.plot_subplots_ensemble_members_and_lagged_adjusted_mean(dictionaries.models, model_time_by_model, model_nao_anoms_by_model, obs_nao_anom, obs_time)

# %%
# Now test the function which plots the impacts of ensemble size on skill
functions.calculate_acc_by_ensemble_size(dictionaries.models, model_nao_anoms_by_model, model_time_by_model, obs_nao_anom, obs_time, step_size=2, num_samples=100)
